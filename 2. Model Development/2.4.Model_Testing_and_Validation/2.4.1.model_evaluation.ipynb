# %% [markdown]
# #### Model Evaluation

# %% [markdown]
# #### Step 1- Load Dependencies

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../../style_Matplotlib_charts.mplstyle')
from sklearn.linear_model import LinearRegression
import pickle

# %% [markdown]
# #### Step 2 - Load Model for Testing

# %%
filename = 'my_saved_model_v1.sav'
model_A = pickle.load(open(filename, 'rb'))

# %% [markdown]
# #### Step 3 - Open Test Data and Store as Variable Array Data Objects

# %%
testing_data = pd.read_csv('2.4.1.testing_data.csv')

# Load the testing data
x_test = testing_data[['age', 'Risk%', 'active', 'meanBP', 'gender']]  # Features
y_test = testing_data['cardio']  # Target

# Make predictions on the test data
y_pred_test = model_A.predict(x_test)

# Scatter plot: Predictions vs Actual Target (Test Data)
plt.figure(figsize=(8, 6))
plt.scatter(range(len(y_test)), y_pred_test, color='blue', label='Predicted Target (Test)', alpha=0.6)
plt.scatter(range(len(y_test)), y_test, color='red', label='Actual Target (Test)', alpha=0.6, marker='x')
plt.title("Predictions vs Actual Target (Test Data)")
plt.xlabel("Data Point Index")
plt.ylabel("Cardiovascular Disease (0 = No, 1 = Yes)")
plt.legend()
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# #### Step 4 - Calculate the Test Score Based on Accuracy
