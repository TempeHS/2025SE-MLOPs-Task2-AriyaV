# %% [markdown]
# #### Model Evaluation

# %% [markdown]
# #### Step 1- Load Dependencies

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../../style_Matplotlib_charts.mplstyle')
import pickle
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# #### Load Model for Testing

# %% [markdown]
# ##### Open and Parse Test Data

# %%
filename_original = 'my_saved_model_original_dataset.sav'
filename_feature_engineered = 'my_saved_model_feature_engineered_dataset.sav'
original_dataset_model= pickle.load(open(filename_original, 'rb'))
feature_engineered_dataset_model = pickle.load(open(filename_feature_engineered, 'rb'))

# %% [markdown]
# ### Original Dataset Model Evaluation

# %% [markdown]
# Store data as variable array data objects

# %%
x_col = ['cholesterol', 'weight']  # Specify both features
testing_data = pd.read_csv('2.4.1.testing_data.csv')

# Extract both features into x_test
x_test = np.array(testing_data[x_col])  # Shape will be (n_samples, 2)
y_test = np.array(testing_data['cardio'])

# Verify the shape of x_test
print(f"x_test shape: {x_test.shape}")  # Should be (n_samples, 2)
# Out:
# x_test shape: (15627, 2)

# %% [markdown]
# ##### Plot Data Features, Target and Logistic Regression Model

# %%
# Create a 3D scatter plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot actual target values
ax.scatter(x_test[:, 0], x_test[:, 1], y_test, c='r', marker='x', label='Actual')

# Plot predicted target values
ax.scatter(x_test[:, 0], x_test[:, 1], y_pred, c='b', marker='o', label='Predicted')

# Set labels and title
ax.set_title("Logistic Regression Model Evaluation")
ax.set_xlabel("Cholesterol")
ax.set_ylabel("Weight")
ax.set_zlabel("Target (cardio)")
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ##### Score Based Evaluation of Model Accuracy -

# %%
test_score = original_dataset_model.score(x_test, y_test)
print(f'Training data score of original dataset model is: {test_score}')
# Out:
# Training data score: 0.6078581941511486
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Evaluation - Feature Engineered Dataset Model

# %% [markdown]
# Store data as variable array data objects

# %%
x_col = ['BMI', 'Risk','meanBP']  # Specify both features
testing_data = pd.read_csv('2.4.1.testing_data.csv')

# Extract both features into x_test
x_test = np.array(testing_data[x_col])  # Shape will be (n_samples, 3)
y_test = np.array(testing_data['cardio'])

# Verify the shape of x_test
print(f"x_test shape: {x_test.shape}")  # Should be (n_samples, 2)
# Out:
# x_test shape: (15627, 3)

# %% [markdown]
# ##### Plot Data Features, Target and Logistic Regression Model

# %%
y_pred = feature_engineered_dataset_model.predict(x_test)

# Create a 3D scatter plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot actual target values
ax.scatter(x_test[:, 0], x_test[:, 1], y_test, c='r', marker='x', label='Actual')

# Plot predicted target values
ax.scatter(x_test[:, 0], x_test[:, 1], y_pred, c='b', marker='o', label='Predicted')

# Set labels and title
ax.set_title("Logistic Regression Model Evaluation")
ax.set_xlabel("BMI")
ax.set_ylabel("Risk")
ax.set_zlabel("Target (cardio)")
ax.legend()

# Show the plot
plt.show()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ##### Score Based Evaluation of Model Accuracy -

# %%
test_score = feature_engineered_dataset_model.score(x_test, y_test)
print(f'Training data score of feature engineered dataset model is: {test_score}')
# Out:
# Training data score of feature engineered dataset model is: 0.48921738017533756
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
